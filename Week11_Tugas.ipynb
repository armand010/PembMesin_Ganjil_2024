# %% [markdown]
# <a href="https://colab.research.google.com/github/armand010/PembMesin_Ganjil_2024/blob/main/Week11_Tugas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tugas
# 1. Modifikasi model CNN pada praktikum 2 sehingga didapatkan akurasi testing lebih dari 80%.
#
# 2. Buatlah model CNN untuk klasifikasi dataset MNIST.

# %% [markdown]
# ## Modifikasi model CNN pada praktikum 2 sehingga didapatkan akurasi testing lebih dari 80%

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# Load dan preprocessing data
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
# Data augmentation untuk mengurangi overfitting
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# Membuat model dengan arsitektur yang lebih dalam
model = models.Sequential([
    # Data augmentation layer
    layers.Input(shape=(32, 32, 3)),
    data_augmentation,

    # Block 1
    layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Block 2
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Block 3
    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Fully Connected layers
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(10)
])

# Learning rate scheduling
initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=1000,
    decay_rate=0.9,
    staircase=True)

# Compile model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=5,
    restore_best_weights=True
)

# Train model
history = model.fit(
    train_images,
    train_labels,
    epochs=50,
    batch_size=64,
    validation_data=(test_images, test_labels),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 782/782 [==============================] - 53s 65ms/step - loss: 1.7489 - accuracy: 0.4067 - val_loss: 1.5836 - val_accuracy: 0.4658
# Epoch 2/50
# 782/782 [==============================] - 50s 64ms/step - loss: 1.2807 - accuracy: 0.5416 - val_loss: 1.3165 - val_accuracy: 0.5571
# Epoch 3/50
# 782/782 [==============================] - 51s 66ms/step - loss: 1.1139 - accuracy: 0.6043 - val_loss: 1.2113 - val_accuracy: 0.5923
# Epoch 4/50
# 782/782 [==============================] - 51s 65ms/step - loss: 1.0157 - accuracy: 0.6419 - val_loss: 1.0113 - val_accuracy: 0.6523
# Epoch 5/50
# 782/782 [==============================] - 51s 65ms/step - loss: 0.9421 - accuracy: 0.6689 - val_loss: 0.9245 - val_accuracy: 0.6800
# Epoch 6/50
# 782/782 [==============================] - 51s 66ms/step - loss: 0.8903 - accuracy: 0.6889 - val_loss: 0.8288 - val_accuracy: 0.7154
# Epoch 7/50
# 782/782 [==============================] - 52s 66ms/step - loss: 0.8357 - accuracy: 0.7092 - val_loss: 0.8756 - val_accuracy: 0.7038
# Epoch 8/50
# 782/782 [==============================] - 52s 66ms/step - loss: 0.7981 - accuracy: 0.7230 - val_loss: 0.7439 - val_accuracy: 0.7467
# Epoch 9/50
# 782/782 [==============================] - 52s 67ms/step - loss: 0.7663 - accuracy: 0.7334 - val_loss: 0.7394 - val_accuracy: 0.7499
# Epoch 10/50
# 782/782 [==============================] - 52s 66ms/step - loss: 0.7408 - accuracy: 0.7432 - val_loss: 0.7700 - val_accuracy: 0.7367
# Epoch 11/50
# 782/782 [==============================] - 52s 66ms/step - loss: 0.7099 - accuracy: 0.7559 - val_loss: 0.6901 - val_accuracy: 0.7654
# Epoch 12/50
# 782/782 [==============================] - 50s 64ms/step - loss: 0.6785 - accuracy: 0.7647 - val_loss: 0.6657 - val_accuracy: 0.7743
# Epoch 13/50
# 782/782 [==============================] - 51s 65ms/step - loss: 0.6692 - accuracy: 0.7671 - val_loss: 0.6277 - val_accuracy: 0.7824
# Epoch 14/50
# 782/782 [==============================] - 51s 65ms/step - loss: 0.6488 - accuracy: 0.7739 - val_loss: 0.6254 - val_accuracy: 0.7857
# Epoch 15/50
# 782/782 [==============================] - 51s 65ms/step - loss: 0.6287 - accuracy: 0.7814 - val_loss: 0.5937 - val_accuracy: 0.8002
# Epoch 16/50
# 782/782 [==============================] - 51s 66ms/step - loss: 0.6178 - accuracy: 0.7842 - val_loss: 0.5623 - val_accuracy: 0.8090
# Epoch 17/50
# 782/782 [==============================] - 51s 65ms/step - loss: 0.6018 - accuracy: 0.7932 - val_loss: 0.6107 - val_accuracy: 0.7964
# Epoch 39/50
# 782/782 [==============================] - 52s 67ms/step - loss: 0.4752 - accuracy: 0.8350 - val_loss: 0.4754 - val_accuracy: 0.8386
# Epoch 40/50
# 782/782 [==============================] - 53s 68ms/step - loss: 0.4813 - accuracy: 0.8332 - val_loss: 0.4707 - val_accuracy: 0.8405
# Epoch 41/50
# 782/782 [==============================] - 52s 67ms/step - loss: 0.4794 - accuracy: 0.8340 - val_loss: 0.4755 - val_accuracy: 0.8393
# Epoch 42/50
# 782/782 [==============================] - 52s 67ms/step - loss: 0.4782 - accuracy: 0.8329 - val_loss: 0.4687 - val_accuracy: 0.8414
# Epoch 43/50
# 782/782 [==============================] - 52s 66ms/step - loss: 0.4793 - accuracy: 0.8330 - val_loss: 0.4685 - val_accuracy: 0.8423

# %%
# Evaluate model
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print(f"\nTest accuracy: {test_acc:.4f}")

# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 313/313 - 3s - loss: 0.4659 - accuracy: 0.8445 - 3s/epoch - 11ms/step
#
# Test accuracy: 0.8445

# %% [markdown]
# ## Buatlah model CNN untuk klasifikasi dataset MNIST.

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
from keras.utils import to_categorical

print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255
Y_train = to_categorical(y_train, num_classes=10)
Y_test = to_categorical(y_test, num_classes=10)
# Out:
# X_train shape (60000, 28, 28)
# y_train shape (60000,)
# X_test shape (10000, 28, 28)
# y_test shape (10000,)

# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.models import Sequential

model = Sequential()
model.add(Conv2D(16, kernel_size=(3,3), strides=(1,1),
          padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D(pool_size=(1,1)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))


model.compile(loss='categorical_crossentropy', optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 26, 26, 16)        0
#  D)
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 128)               1384576
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1386026 (5.29 MB)
# Trainable params: 1386026 (5.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history=model.fit(X_train, Y_train, batch_size=128,
                  epochs=20, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 469/469 [==============================] - 4s 10ms/step - loss: 0.1149 - accuracy: 0.9650 - val_loss: 0.0599 - val_accuracy: 0.9789
# Epoch 2/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0854 - accuracy: 0.9743 - val_loss: 0.0557 - val_accuracy: 0.9821
# Epoch 3/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0689 - accuracy: 0.9791 - val_loss: 0.0526 - val_accuracy: 0.9829
# Epoch 4/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0568 - accuracy: 0.9824 - val_loss: 0.0474 - val_accuracy: 0.9842
# Epoch 5/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0484 - accuracy: 0.9842 - val_loss: 0.0478 - val_accuracy: 0.9851
# Epoch 6/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0423 - accuracy: 0.9865 - val_loss: 0.0471 - val_accuracy: 0.9854
# Epoch 7/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0393 - accuracy: 0.9864 - val_loss: 0.0503 - val_accuracy: 0.9845
# Epoch 8/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0329 - accuracy: 0.9890 - val_loss: 0.0487 - val_accuracy: 0.9854
# Epoch 9/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0323 - accuracy: 0.9887 - val_loss: 0.0458 - val_accuracy: 0.9864
# Epoch 10/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0283 - accuracy: 0.9903 - val_loss: 0.0475 - val_accuracy: 0.9856
# Epoch 11/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0266 - accuracy: 0.9911 - val_loss: 0.0532 - val_accuracy: 0.9851
# Epoch 12/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0246 - accuracy: 0.9914 - val_loss: 0.0488 - val_accuracy: 0.9858
# Epoch 13/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0224 - accuracy: 0.9921 - val_loss: 0.0522 - val_accuracy: 0.9863
# Epoch 14/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0224 - accuracy: 0.9924 - val_loss: 0.0519 - val_accuracy: 0.9850
# Epoch 15/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0201 - accuracy: 0.9931 - val_loss: 0.0513 - val_accuracy: 0.9854
# Epoch 16/20
# 469/469 [==============================] - 4s 10ms/step - loss: 0.0185 - accuracy: 0.9935 - val_loss: 0.0576 - val_accuracy: 0.9849
# Epoch 17/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0180 - accuracy: 0.9939 - val_loss: 0.0563 - val_accuracy: 0.9845
# Epoch 18/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0170 - accuracy: 0.9941 - val_loss: 0.0543 - val_accuracy: 0.9860
# Epoch 19/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0615 - val_accuracy: 0.9852
# Epoch 20/20
# 469/469 [==============================] - 4s 10ms/step - loss: 0.0150 - accuracy: 0.9946 - val_loss: 0.0633 - val_accuracy: 0.9853

# %%
# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
